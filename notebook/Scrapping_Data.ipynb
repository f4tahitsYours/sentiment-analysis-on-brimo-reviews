# %%
# !pip install google_play_scraper
# Out:
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.8 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.7

# %%
from google_play_scraper import reviews, Sort
import pandas as pd

# %%
def scrape_brimo_reviews(count=20000, save_to_csv=True, filename='ulasan_brimo.csv'):
    try:
        print("🔍 Mengambil ulasan BRImo dari Google Play Store...")

        # Scraping ulasan
        result, _ = reviews(
            'id.co.bri.brimo',
            lang='id',
            country='id',
            sort=Sort.NEWEST,
            count=count,
            filter_score_with=None
        )

        # Konversi hasil ke DataFrame
        df = pd.DataFrame(result)

        # Simpan ke CSV jika diinginkan
        if save_to_csv:
            df.to_csv(filename, index=False)
            print(f"✅ {len(df)} ulasan berhasil disimpan ke '{filename}'")

        return df

    except Exception as e:
        print(f"❌ Terjadi kesalahan saat mengambil ulasan: {e}")
        return None

# %%
# Panggil fungsi scraping dan simpan hasil ke variabel df
df = scrape_brimo_reviews()

if df is not None:
    df.head()
# Out:
# 🔍 Mengambil ulasan BRImo dari Google Play Store...
# ✅ 20000 ulasan berhasil disimpan ke 'ulasan_brimo.csv'

# %%
df.head()
# Out:
#                                reviewId         userName  \
# 0  75cdc22c-2d6f-4c2d-a644-ef6f4037590a  Pengguna Google
# 1  3e79831d-0982-4b4a-bf47-43641e91abd1  Pengguna Google
# 2  25b529b2-9a4e-41e7-941c-932fda6ee653  Pengguna Google
# 3  c62d660e-fee1-454f-b1d3-a4251e082c90  Pengguna Google
# 4  3d49d286-2728-458e-8510-36ccfc403845  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0                                              bagus      5              0
# 1                                      instan banget      5              0
# 2                                           ok bagus      5              0
# 3  BRImo mempermudah transaksi-transaksi kami.. b...      5              0
# 4                                              Keren      5              0
#
#   reviewCreatedVersion                  at  \
# 0                 None 2025-05-06 15:53:32
# 1                 None 2025-05-06 15:50:13
# 2               2.82.0 2025-05-06 15:49:46
# 3               2.83.0 2025-05-06 15:49:06
# 4                 None 2025-05-06 15:47:08
#
#                                         replyContent           repliedAt  \
# 0  Hai Sobat BRI, terima kasih atas ulasannya. Se... 2025-05-06 17:26:46
# 1  Hai Sobat BRI, terima kasih atas ulasannya. Se... 2025-05-06 17:25:42
# 2  Hai Sobat BRI, terima kasih atas ulasannya. Se... 2025-05-06 17:27:55
# 3  Hai Sobat BRI, terima kasih atas ulasannya. Se... 2025-05-06 17:26:21
# 4  Hai Sobat BRI, terima kasih atas ulasannya. Se... 2025-05-06 17:27:18
#
#   appVersion
# 0       None
# 1       None
# 2     2.82.0
# 3     2.83.0
# 4       None
